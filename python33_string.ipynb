# %% [markdown]
# # 문자열 메서드(String Method)

# %%
s = 'heLLo pyTHon!'  # str 클래스의 인스턴스 생성 
print(s.capitalize())
#> str.capitalize():  문자열의 첫글자만 대문자로 변환, 나머지는 모두 소문자로 변환한 문자열을 리턴
# Out:
# Hello python!

# %%
print(s)
#> str 클래스의 메서드들은 원본 문자열을 변경하지 않고, 새로운 문자열을 생성해서 리턴함!
# str 객체: 변경 불가능한 객체 (immutable object) cf. 튜플
# Out:
# heLLo pyTHon!

# %%
# str(문자열) = 문자들을 원소로 갖는 tuple
print(s[:5])   # slicing
print(s[-3:])
print('py' in s)
# Out:
# heLLo
# on!
# True

# %%
print(s.title())
#> str.title(): 문자열에서 각 단어의 첫글자만 대문자로, 나머지는 소문자로 변환한 문자열을 리턴
# Out:
# Hello Python!

# %%
print(s.upper())
#> str.upper()
# Out:
# HELLO PYTHON!

# %%
print(s.lower())
#> str.lower()
# Out:
# hello python!

# %%
print(s)
print(s.count('L'))
print(s.count('py'))
#> str.count(sub): 문자열에서 sub 문자열이 몇 번 나오는지를 리턴
# Out:
# heLLo pyTHon!
# 2
# 1

# %%
url = 'https://www.google.com/'

# %%
print(url.startswith('http://'))
#> str.startswith(prefix): 문자열이 prefix로 시작하면 True, 그렇지 않으면 False를 리턴
# Out:
# False

# %%
phone = '010-1234-0000'

# %%
print(phone.endswith('0000'))
#> str.endswith(suffix): 문자열이 suffix로 끝나면 True, 그렇지 않으면 False를 리턴
# Out:
# True

# %%
email = 'abc.def@gmail.com'

# %%
idx = email.find('@')
#> str.find(sub): 문자열에서 sub 문자열이 처음 나오는 인덱스를 리턴
# 문자열에서 sub를 찾을 수 없으면 -1을 리턴
print(idx)
print(email[:idx])
# Out:
# 7
# abc.def

# %% [markdown]
# * `str.format(*args, **kwargs) -> str`
#     * `*args`: variable-length argument(가변 길이 인수)
#     * `**kwargs`: variable-length keyword argument(가변 길이 키워드 인수)
#         * p1=v1, p2=v2,  ...

# %%
'2 x 3 = {}'.format(2*3)
# Out:
# '2 x 3 = 6'

# %%
'{} x {} = {}'.format(2, 3, 2*3)
# Out:
# '2 x 3 = 6'

# %%
'{0} x {1} = {2}'.format(2, 3, 2*3)
# Out:
# '2 x 3 = 6'

# %%
'{1} x {2} = {0}'.format(2*3, 2, 3)
# Out:
# '2 x 3 = 6'

# %%
'{0} x {1}, {0} x {2}'.format(2, 3, 4)
# Out:
# '2 x 3, 2 x 4'

# %%
'{left} x {right} = {result}'.format(left=2, right=3, result=2*3)
# Out:
# '2 x 3 = 6'

# %%
left = 2
right = 3
f'{left} x {right} = {left * right}'
# Out:
# '2 x 3 = 6'

# %% [markdown]
# * str.split(): str -> list

# %%
sentence = 'The Holocaust in Slovakia was the systematic dispossession, deportation, and murder of Jews in the Slovak State, a client state of Nazi Germany, during World War II.'

# %%
sentence.split()
#> str.split(): 문자열을 공백 문자열(space, tab, enter)로 쪼개서 리스트를 생성하고 리턴
# Out:
# ['The',
#  'Holocaust',
#  'in',
#  'Slovakia',
#  'was',
#  'the',
#  'systematic',
#  'dispossession,',
#  'deportation,',
#  'and',
#  'murder',
#  'of',
#  'Jews',
#  'in',
#  'the',
#  'Slovak',
#  'State,',
#  'a',
#  'client',
#  'state',
#  'of',
#  'Nazi',
#  'Germany,',
#  'during',
#  'World',
#  'War',
#  'II.']

# %%
date = '2021-01-07'

# %%
date.split('-')
#> str.split(sep): 문자열을 sep로 쪼개서 리스트를 리턴
# Out:
# ['2021', '01', '07']

# %%
time = '16:02:30'
time.split(sep=':')
# Out:
# ['16', '02', '30']

# %% [markdown]
# * str.join(iterable): list -> str

# %%
':'.join(['16', '02', '30'])
# Out:
# '16:02:30'

# %%
'-'.join(['2021', '1', '27'])
# Out:
# '2021-1-27'

# %%
' '.join(['apple', 'banana', 'cherry'])
# Out:
# 'apple banana cherry'

# %%
s = '       Hello, Python!    안녕하세요...   '

# %%
print(s)
print(s.lstrip())
#> str.lastrip(): 문자열의 왼쪽(시작 부분)에 있는 모든 공백 문자들(space, tab, enter)을 제거
print(s.rstrip())
#> str.rstrip(): 문자열의 오른쪽에 있는 공백 제거
print(s.strip())
# Out:
#        Hello, Python!    안녕하세요...
# Hello, Python!    안녕하세요...
#        Hello, Python!    안녕하세요...
# Hello, Python!    안녕하세요...

# %%
'Hello. Python. 안녕.'.replace('.', '')
# str.replace(old, new): 문자열 str에서 old 부분을 new로 대체한 문자열을 리턴
# Out:
# 'Hello Python 안녕'
