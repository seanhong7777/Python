# %% [markdown]
# **URL 형식**
#
# * 프로토콜://도메인이름(or IP주소):포트번호/경로?쿼리스트링
#     * 프로토콜(protocol): http:, https, ...
#     * 도메인(domain) 이름: www.naver.com, www.daum.net, search.daum.net, ...
#     * 포트(Port) 번호: 포트 번호가 80번인 경우는 생략 가능
#     * 쿼리 스트링(query string):
#         * 클라이언트(웹 브라우저)가 서버로 정보를 보낼 때 사용
#         * parameter=value 형식으로 전달
#         * 파라미터가 여러개일 때는 &로 파라미터를 구분
#
# * URL 예
#     * https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&p=1
#     *  https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&p=2
#     *  https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&p=3
#
# * 요청 방식(Request Method):
#     * GET 방식
#         * 클라이언트가 서버로 보내는 정보들을 URL의 query string에 포함시켜서 보내는 방식
#         * 예: 검색, 링크 클릭, ...
#     * POST 방식
#         * 클라이언트가 서버로 보내는 정보들을 HTTP 패킷으로 감싸서 URL에 정보들이 노출되지 않도록 보내는 방식
#         * 예: 로그인, 이메일, ...

# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&p=1'
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
html = response.text.strip()
soup = BeautifulSoup(markup=html, features='html5lib')
selector = 'ul#clusterResultUL > li > div > div > div > a.f_link_b'
            # clusterResultUL > li:nth-child(2) > div > div > div > a
            # clusterResultUL > li:nth-child(4) > div.wrap_cont > div > div > a
            # clusterResultUL > li:nth-child(10) > div.wrap_cont > div > div > a
soup.select(selector)
# Out:
# [<a class="f_link_b" href="http://v.media.daum.net/v/20210131171803074?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26DaU1fFl-BG-9yFZn&amp;pg=1&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16O8sbGdUflWYlfqu4&amp;e3=0&amp;ext=dsid=26DaU1fFl-BG-9yFZn", event, {"cpid": {"value": "16O8sbGdUflWYlfqu4"}});' target="_blank">지멘스 CEO "<b>머신러닝</b>이 향후 5년 제조업 키워드"</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210125140011940?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26hNNIwgETzhmlmWRS&amp;pg=1&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16_-rXIov6CN5sdGtY&amp;e3=0&amp;ext=dsid=26hNNIwgETzhmlmWRS", event, {"cpid": {"value": "16_-rXIov6CN5sdGtY"}});' target="_blank">바이텍씨스템, 데이터로봇과 데이터 사이언스 및 <b>머신러닝</b> 플랫폼...</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210126143704209?f=o" onclick='smartLog(this, "dc=NNS&amp;d=265V43niIYytkd35sL&amp;pg=1&amp;r=3&amp;p=4&amp;rc=10&amp;e1=16sIQ8rx97vi9RHx8w&amp;e3=0&amp;ext=dsid=265V43niIYytkd35sL", event, {"cpid": {"value": "16sIQ8rx97vi9RHx8w"}});' target="_blank"><b>머신러닝</b> 기반 광고자동화플랫폼 '몰로코 클라우드' 출시.. "올해...</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210114144154666?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26oTLuLvI2yil0AY8f&amp;pg=1&amp;r=4&amp;p=4&amp;rc=10&amp;e1=16EJqgUM0mYHaQpZZ-&amp;e3=0&amp;ext=dsid=26oTLuLvI2yil0AY8f", event, {"cpid": {"value": "16EJqgUM0mYHaQpZZ-"}});' target="_blank">오라클, 블록체인 적용한 'DB 21c' 공개.."<b>머신러닝</b>도 자동으로"</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210113172556755?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26lVxS5ujGNlHCryzF&amp;pg=1&amp;r=5&amp;p=4&amp;rc=10&amp;e1=16b9_Haq_djmtbOGBh&amp;e3=0&amp;ext=dsid=26lVxS5ujGNlHCryzF", event, {"cpid": {"value": "16b9_Haq_djmtbOGBh"}});' target="_blank">노영균 한양대 교수, <b>머신러닝</b> 활용 '간 질병' 분류기술 개발</a>,
#  <a class="f_link_b" href="https://cp.news.search.daum.net/p/101999005" onclick='smartLog(this, "dc=NNS&amp;d=26p0SyB6fBrgXx5JXU&amp;pg=1&amp;r=6&amp;p=4&amp;rc=10&amp;e1=16E08jpdW1oC1VWiLC&amp;e3=0&amp;ext=dsid=26p0SyB6fBrgXx5JXU", event, {"cpid": {"value": "16E08jpdW1oC1VWiLC"}});' target="_blank">[5Q 인터뷰] '혼자 공부하는 <b>머신러닝</b>+딥<b>러닝</b>' 박해선 저자</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210113230556734?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26InMUv97LEfRgxBWz&amp;pg=1&amp;r=7&amp;p=4&amp;rc=10&amp;e1=16JQzgnVEpdmOW7h61&amp;e3=0&amp;ext=dsid=26InMUv97LEfRgxBWz", event, {"cpid": {"value": "16JQzgnVEpdmOW7h61"}});' target="_blank">큐앤에이소프, '<b>머신러닝</b> 기반 다차원 데이터 분석' 관련 특허</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210101093825912?f=o" onclick='smartLog(this, "dc=NNS&amp;d=263J7j-rn46itdnnCi&amp;pg=1&amp;r=8&amp;p=4&amp;rc=10&amp;e1=16-Q5H5hEmOLucotTM&amp;e3=0&amp;ext=dsid=263J7j-rn46itdnnCi", event, {"cpid": {"value": "16-Q5H5hEmOLucotTM"}});' target="_blank">구글코리아, '<b>머신 러닝</b> 야학' 2기 모집</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210107164602542?f=o" onclick='smartLog(this, "dc=NNS&amp;d=268Yo-9fFg4TWPToT_&amp;pg=1&amp;r=9&amp;p=4&amp;rc=10&amp;e1=16g1M6O9sOa_X0ZgmV&amp;e3=0&amp;ext=dsid=268Yo-9fFg4TWPToT_", event, {"cpid": {"value": "16g1M6O9sOa_X0ZgmV"}});' target="_blank">시그니아, 세계 최초 <b>머신러닝</b> 기반 보청기 조절 앱 '시그니아 어...</a>,
#  <a class="f_link_b" href="https://cp.news.search.daum.net/p/101975026" onclick='smartLog(this, "dc=NNS&amp;d=26xd4BghE67AWTIMLe&amp;pg=1&amp;r=10&amp;p=4&amp;rc=10&amp;e1=16oM5rNQgj-I38IYh7&amp;e3=0&amp;ext=dsid=26xd4BghE67AWTIMLe", event, {"cpid": {"value": "16oM5rNQgj-I38IYh7"}});' target="_blank">미 기업인 74% “AI·<b>머신러닝</b> 최우선 순위에 둔다”</a>]

# %%
soup.select()

# %%
# 1~5 페이지까지 뉴스 검색 결과의 제목과 URL을 출력
for page in range(1, 4):
    print(f'--- page {page} ---')
    # 검색 URL
    # url = f'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1&q=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D&p={page}'
    # response = requests.get(url)   # request 보내고 response 받음
    
    url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1'
    params={'q':'머신러닝', 'p':page}  # query string의 parameter
    response = requests.get(url, params)

    html = response.text.strip()   # HTML 코드 추출
    soup = BeautifulSoup(markup=html, features='html5lib')  # BS 객체 생성
    selector = 'ul#clusterResultUL > li > div > div > div > a.f_link_b'  # HTML element 선택자
    search_results = soup.select(selector)
    for link in search_results:
        print(link['href'], link.text)
# Out:
# --- page 1 ---
# http://v.media.daum.net/v/20210131171803074?f=o 지멘스 CEO "머신러닝이 향후 5년 제조업 키워드"
# http://v.media.daum.net/v/20210125140011940?f=o 바이텍씨스템, 데이터로봇과 데이터 사이언스 및 머신러닝 플랫폼...
# http://v.media.daum.net/v/20210126143704209?f=o 머신러닝 기반 광고자동화플랫폼 '몰로코 클라우드' 출시.. "올해...
# http://v.media.daum.net/v/20210114144154666?f=o 오라클, 블록체인 적용한 'DB 21c' 공개.."머신러닝도 자동으로"
# http://v.media.daum.net/v/20210113172556755?f=o 노영균 한양대 교수, 머신러닝 활용 '간 질병' 분류기술 개발
# https://cp.news.search.daum.net/p/101999005 [5Q 인터뷰] '혼자 공부하는 머신러닝+딥러닝' 박해선 저자
# http://v.media.daum.net/v/20210113230556734?f=o 큐앤에이소프, '머신러닝 기반 다차원 데이터 분석' 관련 특허
# http://v.media.daum.net/v/20210101093825912?f=o 구글코리아, '머신 러닝 야학' 2기 모집
# http://v.media.daum.net/v/20210107164602542?f=o 시그니아, 세계 최초 머신러닝 기반 보청기 조절 앱 '시그니아 어...
# https://cp.news.search.daum.net/p/101975026 미 기업인 74% “AI·머신러닝 최우선 순위에 둔다”
# --- page 2 ---
# http://v.media.daum.net/v/20201222143915304?f=o 구글과 함께 하는 AI '머신러닝 야학' 2기 시작
# http://v.media.daum.net/v/20201230140729772?f=o 데브옵스·머신러닝..IT분야 연봉 높이는 기술역량 10가지
# https://cp.news.search.daum.net/p/100965828 누구나 쉽게 배우는 머신러닝... 구글, '머신러닝 야학' 연다
# https://cp.news.search.daum.net/p/101885600 스와미 시바수브라마니안 AWS 머신러닝 부사장
# http://v.media.daum.net/v/20201221180415414?f=o [2020 하반기 인기상품]마케팅우수-위세아이텍-머신러닝 자동화플...
# https://cp.news.search.daum.net/p/101964228 [CES 2021 All Digital] 콕스스페이스(CoX Space), 제스처 머신러...
# http://v.media.daum.net/v/20201218164202716?f=o 아마존 CTO "기계간 소통 50%로 커져..머신러닝 중요성 부각"
# http://v.media.daum.net/v/20210105132003673?f=o [올쇼TV] 소닉월 캡쳐클라이언트, 강력한 머신러닝 기반 차세대 ...
# http://v.media.daum.net/v/20210103125504546?f=o 현대모비스, 머신러닝·블록체인 기반 AS부품 관리 시스템 구축
# http://v.media.daum.net/v/20201230134602978?f=o 차량 내 탑승자 인식 정확도 높인 머신러닝 기반 레이더 기술 개발
# --- page 3 ---
# http://v.media.daum.net/v/20210203142151478?f=o 펜타시큐리티, 웹방화벽 '와플' 6.0 출시
# http://v.media.daum.net/v/20201216000105021?f=o 위세아이텍 창립 30주년.."머신러닝·빅데이터 기술력 발판으로 ...
# http://v.media.daum.net/v/20201213160120944?f=o [공공솔루션마켓]위세아이텍 머신러닝자동화 플랫폼 '와이즈프로핏'
# http://v.media.daum.net/v/20201202180927021?f=o AWS, 머신러닝 모델 훈련 칩 '트레이니엄' 공개
# http://v.media.daum.net/v/20210203102349064?f=o SK C&C, 1㎛ 불량품 검수하는 '아이팩토리 스마트 비전' 공개
# http://v.media.daum.net/v/20210203093542508?f=o 뤼이드, 인공지능학회 'AAAI'서 기업 최초로 워크숍 열어
# http://v.media.daum.net/v/20201230114145251?f=o KAIST, 美 CS랭킹서 전체 7위..머신러닝 실적 성장 두드러져
# https://cp.news.search.daum.net/p/102505631 MIT, 단 1mm 크기 선충류 모방 '액체신경망' 개발
# http://v.media.daum.net/v/20210203111159676?f=o "'AI눈'으로 픽셀 단위까지 찾아낸다"
# http://v.media.daum.net/v/20210203101001239?f=o 인간이 잡지 못하는 미세한 차이 찾는 'AI 눈' 나왔다

# %%
# Out:
# [<a class="f_link_b" href="http://v.media.daum.net/v/20210203142151478?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26b82DN0a8TRY1i0kH&amp;pg=3&amp;r=1&amp;p=4&amp;rc=10&amp;e1=16ch37p8Eze2f0phkS&amp;e3=0&amp;ext=dsid=26b82DN0a8TRY1i0kH", event, {"cpid": {"value": "16ch37p8Eze2f0phkS"}});' target="_blank">펜타시큐리티, 웹방화벽 '와플' 6.0 출시</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20201216000105021?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26UsimwQhosnccqgbo&amp;pg=3&amp;r=2&amp;p=4&amp;rc=10&amp;e1=16sIQ8rx97vi9RHx8w&amp;e3=0&amp;ext=dsid=26UsimwQhosnccqgbo", event, {"cpid": {"value": "16sIQ8rx97vi9RHx8w"}});' target="_blank">위세아이텍 창립 30주년.."<b>머신러닝</b>·빅데이터 기술력 발판으로 ...</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20201213160120944?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26IK8C5922S7VMDwNr&amp;pg=3&amp;r=3&amp;p=4&amp;rc=10&amp;e1=16sIQ8rx97vi9RHx8w&amp;e3=0&amp;ext=dsid=26IK8C5922S7VMDwNr", event, {"cpid": {"value": "16sIQ8rx97vi9RHx8w"}});' target="_blank">[공공솔루션마켓]위세아이텍 <b>머신러닝</b>자동화 플랫폼 '와이즈프로핏'</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20201202180927021?f=o" onclick='smartLog(this, "dc=NNS&amp;d=261qBkFbgkzG9IK0hQ&amp;pg=3&amp;r=4&amp;p=4&amp;rc=10&amp;e1=16ch37p8Eze2f0phkS&amp;e3=0&amp;ext=dsid=261qBkFbgkzG9IK0hQ", event, {"cpid": {"value": "16ch37p8Eze2f0phkS"}});' target="_blank">AWS, <b>머신러닝</b> 모델 훈련 칩 '트레이니엄' 공개</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210203102349064?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26YnLXg4C3U2BtS49-&amp;pg=3&amp;r=5&amp;p=4&amp;rc=10&amp;e1=16b9_Haq_djmtbOGBh&amp;e3=0&amp;ext=dsid=26YnLXg4C3U2BtS49-", event, {"cpid": {"value": "16b9_Haq_djmtbOGBh"}});' target="_blank">SK C&amp;C, 1㎛ 불량품 검수하는 '아이팩토리 스마트 비전' 공개</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210203093542508?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26CLDlZSXY-51WBgNg&amp;pg=3&amp;r=6&amp;p=4&amp;rc=10&amp;e1=16EJqgUM0mYHaQpZZ-&amp;e3=0&amp;ext=dsid=26CLDlZSXY-51WBgNg", event, {"cpid": {"value": "16EJqgUM0mYHaQpZZ-"}});' target="_blank">뤼이드, 인공지능학회 'AAAI'서 기업 최초로 워크숍 열어</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20201230114145251?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26cHeBhBe9h8AEjJLL&amp;pg=3&amp;r=7&amp;p=4&amp;rc=10&amp;e1=16sIQ8rx97vi9RHx8w&amp;e3=0&amp;ext=dsid=26cHeBhBe9h8AEjJLL", event, {"cpid": {"value": "16sIQ8rx97vi9RHx8w"}});' target="_blank">KAIST, 美 CS랭킹서 전체 7위..<b>머신러닝</b> 실적 성장 두드러져</a>,
#  <a class="f_link_b" href="https://cp.news.search.daum.net/p/102505631" onclick='smartLog(this, "dc=NNS&amp;d=26njAsZgRliyoy1fD1&amp;pg=3&amp;r=8&amp;p=4&amp;rc=10&amp;e1=16oM5rNQgj-I38IYh7&amp;e3=0&amp;ext=dsid=26njAsZgRliyoy1fD1", event, {"cpid": {"value": "16oM5rNQgj-I38IYh7"}});' target="_blank">MIT, 단 1mm 크기 선충류 모방 '액체신경망' 개발</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210203111159676?f=o" onclick='smartLog(this, "dc=NNS&amp;d=261RWlu9avHbNV8_1I&amp;pg=3&amp;r=9&amp;p=4&amp;rc=10&amp;e1=16qBwBPOYF5ZTPFTIy&amp;e3=0&amp;ext=dsid=261RWlu9avHbNV8_1I", event, {"cpid": {"value": "16qBwBPOYF5ZTPFTIy"}});' target="_blank">"'AI눈'으로 픽셀 단위까지 찾아낸다"</a>,
#  <a class="f_link_b" href="http://v.media.daum.net/v/20210203101001239?f=o" onclick='smartLog(this, "dc=NNS&amp;d=26dAD3lLP1fzBhqmCk&amp;pg=3&amp;r=10&amp;p=4&amp;rc=10&amp;e1=16xPi3xTTvS9eQchSd&amp;e3=0&amp;ext=dsid=26dAD3lLP1fzBhqmCk", event, {"cpid": {"value": "16xPi3xTTvS9eQchSd"}});' target="_blank">인간이 잡지 못하는 미세한 차이 찾는 'AI 눈' 나왔다</a>]

# %%
def daum_news_search(keyword: str, pages: int):
    for page in range(1, pages + 1):
        print(f'--- page {page} ---')
        
        url = 'https://search.daum.net/search?w=news&DA=PGD&enc=utf8&cluster=y&cluster_page=1'
        params={'q':keyword, 'p':page}  # query string의 parameter
        response = requests.get(url, params)

        html = response.text.strip()   # HTML 코드 추출
        soup = BeautifulSoup(markup=html, features='html5lib')  # BS 객체 생성
        selector = 'ul#clusterResultUL > li > div > div > div > a.f_link_b'  # HTML element 선택자
        search_results = soup.select(selector)
        for link in search_results:
            print(link['href'], link.text)

# %%
keyword = input('검색어 입력>>> ')
pages = int(input('검색할 페이지 개수 입력>>> '))
daum_news_search(keyword, pages)
# Out:
# 검색어 입력>>> 딥러닝
# 검색할 페이지 개수 입력>>> 3
# --- page 1 ---
# https://cp.news.search.daum.net/p/102491259 에이디링크, 엣지 AI 추론 위한 딥러닝 가속 플랫폼 DLAP x86 시...
# https://cp.news.search.daum.net/p/102463670 AI 딥러닝 기술로 발전소 클링커 생성 조기감지
# https://cp.news.search.daum.net/p/102478475 딥러닝, "인공지능이 전문의가 놓쳤던 폐암의 찾아"
# https://cp.news.search.daum.net/p/102458344 동서발전, 딥러닝 활용 ‘연소장애 종합감시 시스템’ 구축
# http://v.media.daum.net/v/20210127085259476?f=o 큐앤에이소프트, 딥러닝 기반의 주식 자동 매매 프로그램 '큐아이...
# https://cp.news.search.daum.net/p/102352622 "'알페스','섹테' 영상 꼼짝마~다 잡아낸다"...딥페이크 영상 90%...
# http://v.media.daum.net/v/20210121140017531?f=o 한국뇌연구원, 딥러닝 기반 변이체-AI로 치매 예측한다
# https://cp.news.search.daum.net/p/102221348 딥러닝으로 유방암 진단 오류 줄였다
# http://v.media.daum.net/v/20210115110155548?f=o AI챗봇 '이루다' DB·딥러닝 모델 폐기한다
# http://v.media.daum.net/v/20210115152134087?f=o 'AI 이루다' 개발사, '개인정보 유출 논란' 딥러닝 대화 모델 폐기
# --- page 2 ---
# http://v.media.daum.net/v/20210115105656292?f=o 'AI 이루다' 개발사 "데이터베이스·딥러닝 모델 폐기하겠다"(종합)
# http://v.media.daum.net/v/20210115113350992?f=o 이루다 개발사 "데이터베이스·딥러닝 대화 모델 폐기 결정"
# http://v.media.daum.net/v/20210125122048406?f=o <"AI로 승부수" 속도내는 기업들>KT "딥러닝 권위자 등 특급인재 ...
# http://v.media.daum.net/v/20210125130214212?f=o 세종대-(주)데니어, 인공지능 딥러닝 기반 치과 교정 프로그램 개...
# http://v.media.daum.net/v/20210115113612088?f=o 'AI 이루다' 개발사 "데이터베이스와 딥러닝 대화 모델 폐기"
# http://v.media.daum.net/v/20210120030436271?f=o [신문과 놀자!/눈이 커지는 수학]스스로 학습하는 '딥러닝'에도 ...
# http://v.media.daum.net/v/20210115153231404?f=o 스캐터랩, '이루다' DB·딥러닝 모델 전량 폐기.. "이용자 불안감...
# http://v.media.daum.net/v/20210116090138542?f=o 정보 유출·혐오 발언 'AI 이루다' 개발업체 "DB·딥러닝 모델 폐기"
# http://v.media.daum.net/v/20210115113613090?f=o 스캐터랩 "이루다 DB·딥러닝 모델 폐기..개인정보 동의 절차 강...
# https://cp.news.search.daum.net/p/101999005 [5Q 인터뷰] '혼자 공부하는 머신러닝+딥러닝' 박해선 저자
# --- page 3 ---
# http://v.media.daum.net/v/20210115104522802?f=o 'AI 이루다' 개발사 "데이터베이스·딥러닝 모델 폐기 고려"
# http://v.media.daum.net/v/20210114040501919?f=o [데스크시각] 알고리즘에 따라 딥러닝하면
# https://cp.news.search.daum.net/p/101958456 현대약품, 파미노젠과 AI 딥러닝 기반 신약개발 나선다
# https://cp.news.search.daum.net/p/101914324 뉴로클, “딥러닝 AI 소프트웨어에 대한 교육계의 관심 늘어”
# http://v.media.daum.net/v/20210107090744380?f=o 동해시, 딥러닝 영상기반, 적설·제설 관제시스템 구축
# https://cp.news.search.daum.net/p/101950627 [단독] 현대차, 이스라엘 스타트업 '유브이아이' 투자…딥 러닝 ...
# https://cp.news.search.daum.net/p/102072114 [CES 2021 All Digital] 한국알파시스템, 딥러닝 이용한 어린이 ...
# https://cp.news.search.daum.net/p/101930839 대구銀, 이상금융거래탐지시스템 고도화…딥러닝 탑재
# https://cp.news.search.daum.net/p/101801808 이루다 DB·딥러닝 모델 폐기 결정했지만··· 논란 여전
# https://cp.news.search.daum.net/p/101799662 스캐터랩, ‘이루다’ 학습에 사용된 딥러닝 대화 모델 폐기
